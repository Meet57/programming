# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://rrk90146:9-8n0sqxc9q74fp8@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Out:
# 'Connected: rrk90146@BLUDB'

# %%
import pandas as pd

# %%
CRIME = pd.read_csv('https://ibm.box.com/shared/static/svflyugsr9zbqy5bmowgswqemfpm1x7f.csv')

# %%
SCHOOL = pd.read_csv('https://ibm.box.com/shared/static/f9gjvj1gjmxxzycdhplzt01qtz0s7ew7.csv')

# %%
CENSUS = pd.read_csv('https://ibm.box.com/shared/static/05c3415cbfbtfnr2fx4atenb2sd361ze.csv')

# %%
# %sql select count(*) from CRIME
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(Decimal('533'),)]

# %%
# %sql select * from CRIME LIMIT 10
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(3512276, 'HK587712', '08/28/2004 05:50:56 PM', '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 'FALSE', 'FALSE', 911, 9, 14, 58, '6', 1155838, 1873050, 2004, '02/10/2018 03:50:01 PM', Decimal('41.80744050'), Decimal('-87.70395585'), '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', '06/26/2004 12:40:00 PM', '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 'FALSE', 'FALSE', 1112, 11, 27, 23, '6', 1152206, 1906127, 2004, '02/28/2018 03:56:25 PM', Decimal('41.89827996'), Decimal('-87.71640551'), '(41.898279962, -87.716405505)'),
# ...

# %%
# %sql select count(*) from CRIME where arrest = 'TRUE'
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(Decimal('163'),)]

# %%
# %sql select distinct(count(*)) from CRIME where location_description = 'GAS STATION'
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(Decimal('6'),)]

# %%
# %sql select community_area_name from CENSUS where community_area_name like 'B%'
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# [('Belmont Cragin',),
#  ('Burnside',),
#  ('Brighton Park',),
#  ('Bridgeport',),
#  ('Beverly',)]

# %%
# %sql select community_area_name from CENSUS where community_area_name = 'B%'
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# []

# %%
# %sql select * from SCHOOLS limit 5
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# ...

# %%
# %sql select community_area_number, healthy_school_certified, name_of_school from SCHOOLS limit 4
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(7, 'Yes', 'Abraham Lincoln Elementary School'),
#  (43, 'No', 'Adam Clayton Powell Paideia Community Academy Elementary School'),
#  (70, 'No', 'Adlai E Stevenson Elementary School'),
#  (61, 'No', 'Agustin Lara Elementary Academy')]

# %%
# %%sql select name_of_school, healthy_school_certified
# from SCHOOLS
# where healthy_school_certified = 'Yes' AND community_area_number between 10 and 15
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# [('Rufus M Hitch Elementary School', 'Yes')]

# %%
# %sql select AVG(safety_score) from SCHOOLS
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(Decimal('49.504873'),)]

# %%
# %%sql select community_area_name, AVG(college_enrollment) AS average_college_enrollment
# from SCHOOLS
# group by community_area_name
# order by average_college_enrollment desc limit 5
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# [('ARCHER HEIGHTS', Decimal('2411.500000')),
#  ('MONTCLARE', Decimal('1317.000000')),
#  ('WEST ELSDON', Decimal('1233.333333')),
#  ('BRIGHTON PARK', Decimal('1205.875000')),
#  ('BELMONT CRAGIN', Decimal('1198.833333'))]

# %%
# %%sql select  community_area_name
# from SCHOOLS
# where safety_score = (select MIN(safety_score) from SCHOOLS)
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# [('WASHINGTON PARK',)]

# %%
# %%sql select per_capita_income
# from CENSUS
# where community_area_number = (select community_area_number from SCHOOLS where safety_score = 1)
# Out:
#  * ibm_db_sa://rrk90146:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net/BLUDB
# Done.
# [(13785,)]
